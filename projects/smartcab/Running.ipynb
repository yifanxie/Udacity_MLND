# %%
# Import the visualization code
import visuals as vs
import numpy as np
import random
import pandas as pd
import operator
# Pretty display for notebooks
# %matplotlib inline
from numpy.random import choice
import operator
import scipy

# %%
a=0.01
t=20
np.cos(a*t)
# Out:
# 0.98006657784124163

# %%
np.cos(0)
# Out:
# 1.0

# %%
epsilon=0.1
random_action = [True, False] 
weights = [epsilon, 1-epsilon]

print(choice(random_action, p=weights))
# Out:
# False

# %%
agent.Q
# Out:
# {"('forward', {'light': 'green', 'oncoming': 'forward', 'right': 'forward', 'left': 'forward'})": {'None': 0,
#   'forward': 0,
#   'left': 0,
#   'right': 0},
#  "('forward', {'light': 'green', 'oncoming': 'forward', 'right': 'forward', 'left': None})": {'None': 0,
#   'forward': 0,
#   'left': 0,
#   'right': 0},
#  "('forward', {'light': 'green', 'oncoming': 'forward', 'right': 'right', 'left': 'right'})": {'None': 0,
#   'forward': 0,
#   'left': 0,
#   'right': 0},
#  "('forward', {'light': 'green', 'oncoming': 'forward', 'right': 'right', 'left': None})": {'None': 0,
#   'forward': 0,
#   'left': 0,
#   'right': 0},
#  "('forward', {'light': 'green', 'oncoming': 'forward', 'right': None, 'left': 'forward'})": {'None': 0,
#   'forward': 0,
#   'left': 0,
#   'right': 0},
#  "('forward', {'light': 'green', 'oncoming': 'forward', 'right': None, 'left': None})": {'None': 0,
#   'forward': 0,
#   'left': 0,
#   'right': 0},
# ...

# %%
w='left'
i={'light':'red', 'oncoming': 'left', 'right': 'left', 'left':None}
s=(w,i)

# %%
s1=('left', {'light': 'red', 'oncoming': None, 'right': None, 'left': None})
s2=('left', {'light': 'red', 'oncoming': None, 'right': None, 'left': 'forward'})
s3=('left', {'light': 'green', 'oncoming': 'right', 'right': None, 'left': 'forward'})

# %%
q={}
q[str(s1)]={}
q[str(s1)]['action_0']=0
q[str(s1)]['action_1']=0
q[str(s1)]['action_2']=0
q[str(s1)]['action_3']=1
# q[]

# %%
act=max(q[str(s1)].iteritems(), key=operator.itemgetter(1))[0]

# %%
act[-1]
# Out:
# '3'

# %%
a=11.13

print('a is {:.6}'.format(a))
# Out:
# a is 11.13

# %%
import pandas as pd
sim_no_learning=pd.read_csv('./logs/sim_no-learning.csv')
sim_no_learning.loc[sim_no_learning.testing==False]
# Out:
#     trial testing            parameters  initial_deadline  final_deadline  \
# 0       1   False  {'a': 0.5, 'e': 1.0}                25              17
# 1       2   False  {'a': 0.5, 'e': 1.0}                25               0
# 2       3   False  {'a': 0.5, 'e': 1.0}                25               0
# 3       4   False  {'a': 0.5, 'e': 1.0}                20               9
# 4       5   False  {'a': 0.5, 'e': 1.0}                20               0
# 5       6   False  {'a': 0.5, 'e': 1.0}                20               0
# 6       7   False  {'a': 0.5, 'e': 1.0}                25               0
# 7       8   False  {'a': 0.5, 'e': 1.0}                25               0
# 8       9   False  {'a': 0.5, 'e': 1.0}                20               0
# 9      10   False  {'a': 0.5, 'e': 1.0}                30               0
# 10     11   False  {'a': 0.5, 'e': 1.0}                25               0
# 11     12   False  {'a': 0.5, 'e': 1.0}                20               0
# ...

# %%
reload(vs)
vs.plot_trials('sim_no-learning.csv')

# %%
reload(vs)
vs.plot_trials('sim_no-learning.csv')

# %%
reload(vs)
vs.plot_trials('sim_default-learning.csv')

# %%
reload(vs)
vs.plot_trials('sim_default-learning.csv')

# %%
print(random.randint(0,2))
# Out:
# 2

# %%
3**5*24
# Out:
# 5832

# %%
a=1
b=2
c=(a,b)

# %%
type(c)
# Out:
# tuple

# %%
a='Left'
print('choose random action {}'.format(a))
# Out:
# choose random action Left

# %%
snl=pd.read_csv('./logs/sim_no-learning.csv')

# %%
snl
# Out:
#     trial testing            parameters  initial_deadline  final_deadline  \
# 0       1   False  {'a': 0.5, 'e': 1.0}                20               0
# 1       2   False  {'a': 0.5, 'e': 1.0}                30               0
# 2       3   False  {'a': 0.5, 'e': 1.0}                25               0
# 3       4   False  {'a': 0.5, 'e': 1.0}                30               0
# 4       5   False  {'a': 0.5, 'e': 1.0}                20               0
# 5       6   False  {'a': 0.5, 'e': 1.0}                30               0
# 6       7   False  {'a': 0.5, 'e': 1.0}                25              19
# 7       8   False  {'a': 0.5, 'e': 1.0}                20               0
# 8       9   False  {'a': 0.5, 'e': 1.0}                30               0
# 9      10   False  {'a': 0.5, 'e': 1.0}                25               8
# 10     11   False  {'a': 0.5, 'e': 1.0}                25               0
# 11     12   False  {'a': 0.5, 'e': 1.0}                30               0
# ...
